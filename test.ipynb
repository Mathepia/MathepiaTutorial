# %%
import matplotlib.pyplot as plt
plt.style.use(['science','ieee'])

# %%
import numpy as np
import matplotlib.pyplot as plt
def model(x, p):
   return x ** (2 * p + 1) / (1 + x ** (2 * p))
x = np.linspace(0.75, 1.25, 201)

# %%
fig, ax = plt.subplots()
for p in [10, 15, 20, 30, 50, 100]:
    ax.plot(x, model(x, p), label=p)
ax.legend(title='Order')
ax.set(xlabel='Voltage (mV)')
ax.set(ylabel='Current ($\mu$A)')
ax.autoscale(tight=True)
fig.savefig('fig1.jpg', dpi=300)
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %%
with plt.style.context(['science']):
    fig, ax = plt.subplots()
    for p in [10, 15, 20, 30, 50, 100]:
        ax.plot(x, model(x, p), label=p)
    ax.legend(title='Order')
    ax.set(xlabel='Voltage (mV)')
    ax.set(ylabel='Current ($\mu$A)')
    ax.autoscale(tight=True)
    fig.savefig('figures/fig1.pdf')
    fig.savefig('figures/fig1.jpg', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-99140dce3dbe> in <module>
#       7     ax.set(ylabel='Current ($\mu$A)')
#       8     ax.autoscale(tight=True)
# ----> 9     fig.savefig('figures/fig1.pdf')
#      10     fig.savefig('figures/fig1.jpg', dpi=300)
#      11
#
# F:\Anaconda\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# F:\Anaconda\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#    2219                 if bbox_inches and restore_bbox:
#
# F:\Anaconda\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# F:\Anaconda\lib\site-packages\matplotlib\backends\backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2584             file = filename._file
#    2585         else:
# -> 2586             file = PdfFile(filename, metadata=metadata)
#    2587         try:
#    2588             file.newPage(width, height)
#
# F:\Anaconda\lib\site-packages\matplotlib\backends\backend_pdf.py in __init__(self, filename, metadata)
#     560         self.original_file_like = None
#     561         self.tell_base = 0
# --> 562         fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     563         if not opened:
#     564             try:
#
# F:\Anaconda\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     406             fh = bz2.BZ2File(fname, flag)
#     407         else:
# --> 408             fh = open(fname, flag, encoding=encoding)
#     409         opened = True
#     410     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figures/fig1.pdf'

# %%
with plt.style.context(['science', 'ieee']):
    fig, ax = plt.subplots()
    for p in [10, 20, 50]:
       ax.plot(x, model(x, p), label=p)
       ax.legend(title='Order')
    ax.set(xlabel='Voltage (mV)')
    ax.set(ylabel='Current ($\mu$A)')
    ax.autoscale(tight=True)
    fig.savefig('figures/fig2.pdf')
    fig.savefig('figures/fig2.jpg', dpi=300)

# %%
with plt.style.context(['science', 'scatter']):
    fig, ax = plt.subplots(figsize=(4,4))
    ax.plot([-2, 2], [-2, 2], 'k--')
    ax.fill_between([-2, 2], [-2.2, 1.8], [-1.8, 2.2], color='dodgerblue', alpha=0.2, lw=0)
    for i in range(7):
        x1 = np.random.normal(0, 0.5, 10)
        y1 = x1 + np.random.normal(0, 0.2, 10)
        ax.plot(x1, y1, label=r"$^\#${}".format(i+1))
        ax.legend(title='Sample', loc=2)
        ax.set_xlabel(r"$\log_{10}\left(\frac{L_\mathrm{IR}}{\mathrm{L}_\odot}\right)$")
        ax.set_ylabel(r"$\log_{10}\left(\frac{L_\mathrm{6.2}}{\mathrm{L}_\odot}\right)$")
        ax.set_xlim([-2, 2])
        ax.set_ylim([-2, 2])
        #fig.savefig('figures/fig3.pdf')
        #fig.savefig('figures/fig3.jpg', dpi=300)
